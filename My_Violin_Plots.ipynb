# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel(r"E:\Dream\Dream Research\Mitacs Project\My_Project_Violin_Plots.xlsx")
print(df.head())
#colour={"sky blue", "hot pink", "pink"}
#my_pal = {"QE (90 Ry)": "skyblue", "QE (35 Ry)": "hotpink", "QE (25 Ry)": "pink"}
sns.violinplot(data=df, x="Tungsten violin plot comparison", y="Shielding Values", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.3, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None,palette=None, saturation=0.75, ax=None)
# Out:
#   Tungsten violin plot comparison  Shielding Values  Unnamed: 2  \
# 0                     σ(QE) (ppm)           3433.67         NaN
# 1                     σ(QE) (ppm)           3664.18         NaN
# 2                     σ(QE) (ppm)           3656.32         NaN
# 3                     σ(QE) (ppm)           3562.87         NaN
# 4                     σ(QE) (ppm)           3638.88         NaN
#
#   Tungsten V Plot  Shielding-Values  Unnamed: 5  Unnamed: 6 W-Diff      SV  \
# 0     σ(QE) (ppm)           3433.67         NaN         NaN  D-one  809.06
# 1     σ(QE) (ppm)           3664.18         NaN         NaN  D-one  750.69
# 2     σ(QE) (ppm)           3656.32         NaN         NaN  D-one  780.89
# 3     σ(QE) (ppm)           3562.87         NaN         NaN  D-one  751.90
# 4     σ(QE) (ppm)           3638.88         NaN         NaN  D-one  787.22
#
#    Unnamed: 9  ... Total-PBE-S  D-with-Tot1-QE  Unnamed: 17  σ(Total-1) (ppm)  \
# ...

# %%
sns.violinplot(data=df, x="Tungsten V Plot", y="Shielding-Values", hue=None, order=None, hue_order=None, bw='scott' , scale='area', scale_hue=True, gridsize=100, width=0.5, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None,palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:xlabel='Tungsten V Plot', ylabel='Shielding-Values'>

# %%
sns.violinplot(data=df, x="W-Diff", y="SV", hue=None, order=None, hue_order=None, bw='scott' , scale='area', scale_hue=True, gridsize=100, width=0.5, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None,palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:xlabel='W-Diff', ylabel='SV'>

# %%
sns.violinplot(data=df, x="D-Total-1", y="S-V", hue=None, order=None, hue_order=None, bw='scott' , scale='area', scale_hue=True, gridsize=100, width=0.5, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None,palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:xlabel='D-Total-1', ylabel='S-V'>

# %%
sns.violinplot(data=df, x=None, y="Total-Scalar", hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='Total-Scalar'>

# %%
sns.violinplot(data=df, x=None, y="Total-SO", hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='Total-SO'>

# %%
sns.violinplot(data=df, x=None, y="Total-PBE-S", hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='Total-PBE-S'>

# %%
sns.violinplot(data=df, x=None, y="D-with-Tot1-QE", hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='D-with-Tot1-QE'>

# %%
sns.violinplot(data=df, x=None, y="σ(Total-1) (ppm)", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='σ(Total-1) (ppm)'>

# %%
sns.violinplot(data=df, x=None, y="σ(Total-2) (ppm)", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="skyblue", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='σ(Total-2) (ppm)'>

# %%
sns.violinplot(data=df, x=None, y="σ(PBE,scalar) (ppm)", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="c", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='σ(PBE,scalar) (ppm)'>

# %%
sns.violinplot(data=df, x=None, y="σ(ADF, PBE SO) (ppm)", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.25, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="c", palette=None, saturation=0.75, ax=None)
# Out:
# <AxesSubplot:ylabel='σ(ADF, PBE SO) (ppm)'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel(r"E:\Dream\Dream Research\Mitacs Project\Linear_Regression\Data_in_excel1.xlsx")
print(df.head())
#colour={"sky blue", "hot pink", "pink"}
#my_pal = {"QE (90 Ry)": "skyblue", "QE (35 Ry)": "hotpink", "QE (25 Ry)": "pink"}
#sns.violinplot(data=data, y="R^2", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.3, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="pink",palette=None, saturation=0.75, ax=None)
sns.swarmplot(data=data, y="R^2",size=2)
#plt.ylim(0, 1)
#sns.swarmplot(data=data, y="R^2", dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, hue_norm=None, native_scale=False, formatter=None, legend='auto', warn_thresh=0.05, ax=None)
#sns.boxplot(data=data, y="R^2")
# Out:
#   Tungsten violin plot comparison  Shielding Values  Unnamed: 2  \
# 0                     σ(QE) (ppm)           3433.67         NaN
# 1                     σ(QE) (ppm)           3664.18         NaN
# 2                     σ(QE) (ppm)           3656.32         NaN
# 3                     σ(QE) (ppm)           3562.87         NaN
# 4                     σ(QE) (ppm)           3638.88         NaN
#
#   Tungsten V Plot  Shielding-Values  Unnamed: 5  Unnamed: 6 W-Diff      SV  \
# 0     σ(QE) (ppm)           3433.67         NaN         NaN  D-one  809.06
# 1     σ(QE) (ppm)           3664.18         NaN         NaN  D-one  750.69
# 2     σ(QE) (ppm)           3656.32         NaN         NaN  D-one  780.89
# 3     σ(QE) (ppm)           3562.87         NaN         NaN  D-one  751.90
# 4     σ(QE) (ppm)           3638.88         NaN         NaN  D-one  787.22
#
#    Unnamed: 9  ... Total-PBE-S  D-with-Tot1-QE  Unnamed: 17  σ(Total-1) (ppm)  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel(r"E:\Dream\Dream Research\Mitacs Project\Linear_Regression\Data_in_excel1.xlsx")
print(df.head())
#colour={"sky blue", "hot pink", "pink"}
#my_pal = {"QE (90 Ry)": "skyblue", "QE (35 Ry)": "hotpink", "QE (25 Ry)": "pink"}
#sns.violinplot(data=data, y="R^2", hue=None, order=None, hue_order=None, bw='scott', scale='area', scale_hue=True, gridsize=100, width=0.3, inner='box', split=False, dodge=True, orient=None, linewidth=None, color="pink",palette=None, saturation=0.75, ax=None)
sns.swarmplot(data=data, y="RMSE",size=2)
# Out:
#   Tungsten violin plot comparison  Shielding Values  Unnamed: 2  \
# 0                     σ(QE) (ppm)           3433.67         NaN
# 1                     σ(QE) (ppm)           3664.18         NaN
# 2                     σ(QE) (ppm)           3656.32         NaN
# 3                     σ(QE) (ppm)           3562.87         NaN
# 4                     σ(QE) (ppm)           3638.88         NaN
#
#   Tungsten V Plot  Shielding-Values  Unnamed: 5  Unnamed: 6 W-Diff      SV  \
# 0     σ(QE) (ppm)           3433.67         NaN         NaN  D-one  809.06
# 1     σ(QE) (ppm)           3664.18         NaN         NaN  D-one  750.69
# 2     σ(QE) (ppm)           3656.32         NaN         NaN  D-one  780.89
# 3     σ(QE) (ppm)           3562.87         NaN         NaN  D-one  751.90
# 4     σ(QE) (ppm)           3638.88         NaN         NaN  D-one  787.22
#
#    Unnamed: 9  ... Total-PBE-S  D-with-Tot1-QE  Unnamed: 17  σ(Total-1) (ppm)  \
# ...
